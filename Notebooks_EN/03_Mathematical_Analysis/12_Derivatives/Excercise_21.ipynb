# %% [markdown]
# <a href="https://colab.research.google.com/github/canliy961/Math-2024-25-Winter/blob/main/Notebooks_EN/03_Mathematical_Analysis/12_Derivatives/Excercise_21.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 21. Derivatives
#
# 1. Compute derivatives of functions:
#    * $y(x) = -3x+3$
#    * $y(x) = \pi x + \sin(1)$
#    * $y(x) = 4+\sin(2)$
#    * $y(x) = 2x^3 - 3x^2 + 8x - 9$
#    * $y(x) = 6 x^{1/3}$
#    * $y(x) = \sqrt{x}$
#    * $y(x) = \cos(x) + \sin(x)$
#    * $y(x) = 2\sin(x) \cos(x)$
#    * $y(x) = x\sin(x)$
#    * $y(x) = (x+1)(x+1)$
#    * $y(x) = \frac{x}{x+1}$
#    * $y(x) = (x+1)\exp(x)$
#    * $y(x) = \sin(x^2)$
#    * $y(x) = \exp(-2x)$
#    * $y(x) = \frac{1}{\sin(x+1)}$
#    * $y(x) = \sqrt{2x+1}$
#
# 2. Prove:
#    - $\frac{d}{dx} (\ln(\sin(x))) = \cot(x)$
#
# 3. For $f(x) = \cos(x)$, verify that $f''(x) = -f(x)$.
#
# 4. Using de l'Hospital's Rule, find the improper limits:
#    - $\displaystyle \lim_{x\to 0} \frac{\sin{x}}{x}$
#
#    - $\displaystyle \lim_{x\to \infty} \frac{\ln x}{x}$
#
#    - $\displaystyle \lim_{x\to \infty} \frac{\exp(x)}{x}$
#
# 5. In physics, the position of a particle is given by $x(t) = 3t^2 - 6t + 1$. Find the velocity $V(t)=x'(t)$ and acceleration $a(t)=V'(t)=x''(t)$ of the particle at time $t = 2$.

# %% [markdown]
# ### 1. Compute the derivatives of the following functions:
#
# ### (a) \( y(x) = -3x + 3 \)
#
# The derivative of \( y(x) = -3x + 3 \) with respect to \( x \) is:
#
# $$
# \frac{dy}{dx} = -3
# $$
#
# ---
#
# ### (b) \( y(x) = \pi x + \sin(1) \)
#
# The derivative of \( y(x) = \pi x + \sin(1) \) is:
#
# $$
# \frac{dy}{dx} = \pi
# $$
#
# Since \( \sin(1) \) is a constant, its derivative is zero.
#
# ---
#
# ### (c) \( y(x) = 4 + \sin(2) \)
#
# The derivative of \( y(x) = 4 + \sin(2) \) is:
#
# $$
# \frac{dy}{dx} = 0
# $$
#
# Since both 4 and \( \sin(2) \) are constants, their derivatives are zero.
#
# ---
#
# ### (d) \( y(x) = 2x^3 - 3x^2 + 8x - 9 \)
#
# The derivative of \( y(x) = 2x^3 - 3x^2 + 8x - 9 \) is:
#
# $$
# \frac{dy}{dx} = 6x^2 - 6x + 8
# $$
#
# ---
#
# ### (e) \( y(x) = 6x^{1/3} \)
#
# The derivative of \( y(x) = 6x^{1/3} \) using the power rule is:
#
# $$
# \frac{dy}{dx} = 6 \cdot \frac{1}{3} x^{-2/3} = 2x^{-2/3}
# $$
#
# ---
#
# ### (f) \( y(x) = x \)
#
# The derivative of \( y(x) = x \) is:
#
# $$
# \frac{dy}{dx} = 1
# $$
#
# ---
#
# ### (g) \( y(x) = \cos(x) + \sin(x) \)
#
# The derivative of \( y(x) = \cos(x) + \sin(x) \) is:
#
# $$
# \frac{dy}{dx} = -\sin(x) + \cos(x)
# $$
#
# ---
#
# ### (h) \( y(x) = 2\sin(x)\cos(x) \)
#
# We apply the product rule to \( y(x) = 2\sin(x)\cos(x) \):
#
# $$
# \frac{dy}{dx} = 2 \left( \cos(x) \cdot \cos(x) - \sin(x) \cdot \sin(x) \right) = 2\cos(2x)
# $$
#
# ---
#
# ### (i) \( y(x) = x \sin(x) \)
#
# Using the product rule for \( y(x) = x \sin(x) \), we get:
#
# $$
# \frac{dy}{dx} = \sin(x) + x \cos(x)
# $$
#
# ---
#
# ### (j) \( y(x) = (x + 1)(x + 1) \)
#
# First, simplify \( y(x) = (x + 1)^2 \), then differentiate:
#
# $$
# \frac{dy}{dx} = 2(x + 1)
# $$
#
# ---
#
# ### (k) \( y(x) = \frac{x}{x + 1} \)
#
# Using the quotient rule for \( y(x) = \frac{x}{x + 1} \):
#
# $$
# \frac{dy}{dx} = \frac{(x + 1)(1) - x(1)}{(x + 1)^2} = \frac{1}{(x + 1)^2}
# $$
#
# ---
#
# ### (l) \( y(x) = (x + 1) \exp(x) \)
#
# Using the product rule for \( y(x) = (x + 1) \exp(x) \):
#
# $$
# \frac{dy}{dx} = \exp(x) + (x + 1) \exp(x) = (x + 2) \exp(x)
# $$
#
# ---
#
# ### (m) \( y(x) = \sin(x^2) \)
#
# Using the chain rule for \( y(x) = \sin(x^2) \):
#
# $$
# \frac{dy}{dx} = \cos(x^2) \cdot 2x = 2x \cos(x^2)
# $$
#
# ---
#
# ### (n) \( y(x) = \exp(-2x) \)
#
# The derivative of \( y(x) = \exp(-2x) \) is:
#
# $$
# \frac{dy}{dx} = -2 \exp(-2x)
# $$
#
# ---
#
# ### (o) \( y(x) = \frac{1}{\sin(x + 1)} \)
#
# Using the chain rule for \( y(x) = \frac{1}{\sin(x + 1)} \):
#
# $$
# \frac{dy}{dx} = - \frac{\cos(x + 1)}{\sin^2(x + 1)}
# $$
#
# ---
#
# ### (p) \( y(x) = 2x + 1 \)
#
# The derivative of \( y(x) = 2x + 1 \) is:
#
# $$
# \frac{dy}{dx} = 2
# $$

# %% [markdown]
# ### 2. Prove
#
# $$
# \frac{d}{dx} \left( \ln(\sin(x)) \right) = \cot(x)
# $$
#
# ### Proof:
#
# We will differentiate \( \ln(\sin(x)) \) using the chain rule.
#
# Let \( y = \ln(\sin(x)) \). To differentiate, we apply the chain rule, which states:
#
# $$
# \frac{d}{dx} \ln(u) = \frac{1}{u} \cdot \frac{du}{dx}
# $$
#
# In this case, \( u = \sin(x) \). Therefore, we have:
#
# $$
# \frac{d}{dx} \ln(\sin(x)) = \frac{1}{\sin(x)} \cdot \frac{d}{dx} \sin(x)
# $$
#
# Now, we differentiate \( \sin(x) \):
#
# $$
# \frac{d}{dx} \sin(x) = \cos(x)
# $$
#
# Thus, the derivative becomes:
#
# $$
# \frac{d}{dx} \ln(\sin(x)) = \frac{1}{\sin(x)} \cdot \cos(x)
# $$
#
# Simplifying:
#
# $$
# \frac{\cos(x)}{\sin(x)} = \cot(x)
# $$
#
# Therefore, we have:
#
# $$
# \frac{d}{dx} \left( \ln(\sin(x)) \right) = \cot(x)
# $$

# %% [markdown]
# ### 3. For \( f(x) = \cos(x) \), verify that \( f''(x) = -f(x) \).
#
# ### Solution:
#
# First, we compute the first derivative of \( f(x) = \cos(x) \):
#
# $$
# f'(x) = -\sin(x)
# $$
#
# Next, we compute the second derivative:
#
# $$
# f''(x) = -\cos(x)
# $$
#
# Thus, we have:
#
# $$
# f''(x) = -f(x)
# $$
#
# Hence, we verify that:
#
# $$
# f''(x) = -f(x)
# $$

# %% [markdown]
# ### 4. Using de L'Hopital's Rule, find the following improper limits:
#
# (a)
#
# $$ \lim_{x \to 0} \frac{\sin(x)}{x} $$
#
# (b)
#
# $$ \lim_{x \to \infty} \frac{\ln(x)}{x} $$
#
# (c)
#
# $$ \lim_{x \to \infty} \frac{\exp(x)}{x} $$
#
# ---
#
# ### Solution:
#
# #### (a) Limit of \( \frac{\sin(x)}{x} \) as \( x \to 0 \):
#
# We are given the limit:
#
# $$ \lim_{x \to 0} \frac{\sin(x)}{x} $$
#
# This is an indeterminate form \( \frac{0}{0} \), so we apply L'Hopital's Rule. Differentiate the numerator and the denominator:
#
# - The derivative of \( \sin(x) \) is \( \cos(x) \),
# - The derivative of \( x \) is \( 1 \).
#
# Thus, applying L'Hopital's Rule:
#
# $$ \lim_{x \to 0} \frac{\sin(x)}{x} = \lim_{x \to 0} \frac{\cos(x)}{1} $$
#
# Since \( \cos(0) = 1 \), we have:
#
# $$ \lim_{x \to 0} \frac{\sin(x)}{x} = 1 $$
#
# #### (b) Limit of \( \frac{\ln(x)}{x} \) as \( x \to \infty \):
#
# Now consider the limit:
#
# $$ \lim_{x \to \infty} \frac{\ln(x)}{x} $$
#
# This is also an indeterminate form \( \frac{\infty}{\infty} \), so we apply L'Hopital's Rule. Differentiate the numerator and the denominator:
#
# - The derivative of \( \ln(x) \) is \( \frac{1}{x} \),
# - The derivative of \( x \) is \( 1 \).
#
# Thus, applying L'Hopital's Rule:
#
# $$ \lim_{x \to \infty} \frac{\ln(x)}{x} = \lim_{x \to \infty} \frac{\frac{1}{x}}{1} = \lim_{x \to \infty} \frac{1}{x} $$
#
# As \( x \to \infty \), \( \frac{1}{x} \to 0 \), so we have:
#
# $$ \lim_{x \to \infty} \frac{\ln(x)}{x} = 0 $$
#
# #### (c) Limit of \( \frac{\exp(x)}{x} \) as \( x \to \infty \):
#
# Finally, consider the limit:
#
# $$ \lim_{x \to \infty} \frac{\exp(x)}{x} $$
#
# This is an indeterminate form \( \frac{\infty}{\infty} \), so we apply L'Hopital's Rule. Differentiate the numerator and the denominator:
#
# - The derivative of \( \exp(x) \) is \( \exp(x) \),
# - The derivative of \( x \) is \( 1 \).
#
# Thus, applying L'Hopital's Rule:
#
# $$ \lim_{x \to \infty} \frac{\exp(x)}{x} = \lim_{x \to \infty} \frac{\exp(x)}{1} = \lim_{x \to \infty} \exp(x) $$
#
# Since \( \exp(x) \to \infty \) as \( x \to \infty \), we have:
#
# $$ \lim_{x \to \infty} \frac{\exp(x)}{x} = \infty $$
#
# ---
#
# ### Final Answers:
#
# (a)
#
# $$ \lim_{x \to 0} \frac{\sin(x)}{x} = 1 $$
#
# (b)
#
# $$ \lim_{x \to \infty} \frac{\ln(x)}{x} = 0 $$
#
# (c)
#
# $$ \lim_{x \to \infty} \frac{\exp(x)}{x} = \infty $$

# %% [markdown]
# ### 5. In physics, the position of a particle is given by:
#
# $$ x(t) = 3t^2 - 6t + 1 $$
#
# Find the velocity \( V(t) = x'(t) \) and acceleration \( a(t) = V'(t) = x''(t) \) of the particle at time \( t = 2 \).
#
# ---
#
# ### Solution:
#
# #### 1. Velocity:
#
# The velocity \( V(t) \) is the first derivative of the position function \( x(t) \) with respect to \( t \).
#
# Differentiate \( x(t) = 3t^2 - 6t + 1 \) with respect to \( t \):
#
# $$ V(t) = x'(t) = \frac{d}{dt}(3t^2 - 6t + 1) $$
#
# Using the power rule:
#
# $$ V(t) = 6t - 6 $$
#
# Now, evaluate the velocity at \( t = 2 \):
#
# $$ V(2) = 6(2) - 6 = 12 - 6 = 6 $$
#
# Thus, the velocity at \( t = 2 \) is:
#
# $$ V(2) = 6 $$
#
# #### 2. Acceleration:
#
# The acceleration \( a(t) \) is the derivative of the velocity function \( V(t) \), or equivalently, the second derivative of the position function \( x(t) \).
#
# Now, differentiate \( V(t) = 6t - 6 \) with respect to \( t \):
#
# $$ a(t) = V'(t) = \frac{d}{dt}(6t - 6) = 6 $$
#
# So, the acceleration is constant:
#
# $$ a(t) = 6 $$
#
# Thus, the acceleration at \( t = 2 \) is:
#
# $$ a(2) = 6 $$
#
# ---
#
# ### Final Answer:
#
# At \( t = 2 \), the velocity and acceleration are:
#
# $$ V(2) = 6, \quad a(2) = 6 $$
#
# Therefore, the velocity and acceleration of the particle at \( t = 2 \) are both:
#
# $$ \boxed{6} $$
